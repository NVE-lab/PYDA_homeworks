# %% [markdown]
# # Домашнее задание «Продвинутый pandas 2»

# %% [markdown]
# ### Задание 1
#
# Используйте файл с оценками фильмов ml-latest-small/ratings.csv. Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок. Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp для данного значения userId.

# %%
import pandas as pd

# %%
# По данным файла readme.txt данные в файле ratings.csv отсортированы по userId
#('The lines within this file are ordered first by userId'),
# соответственно, можно читать файл построчно

ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
def calc (user_data):
    calc_max = max(x[1] for x in user_data)
    calc_min = min(x[1] for x in user_data)
    calc_avg = (calc_max - calc_min)
    return calc_avg

# %%
previous_user = None
user_data = []

with open('ratings.csv') as f:
    header = f.readline()
             
    for line in f:
        line = line.strip().split(',')
        userId, movieId, rating, timestamp = line
        timestamp = float(timestamp)
        
        if previous_user == None:
            previous_user = userId
        else:
            if userId == previous_user:
                user_data.append([userId, timestamp])
            else:
                if len(user_data)>100:
                    calculation = calc(user_data)
                    print(previous_user, calculation)
                                        
                    user_data = [] #обнуление датафрейма
                    user_data.append([userId, timestamp]) #Накопление информации о новом userId
                    previous_user = userId
                else:
                    user_data = [] #обнуление датафрейма
                    user_data.append([userId, timestamp]) #Накопление информации о новом userId
                    previous_user = userId
# Out:
# 4 203560.0
# 8 85187.0
# 15 471393496.0
# 17 8053.0
# 19 5282.0
# 21 1365432.0
# 22 91491.0
# 23 18342129.0
# 26 20267261.0
# 30 115852276.0
# 33 4332211.0
# 34 2835.0
# 36 5949290.0
# 38 59971665.0
# 41 15930495.0
# 43 13885.0
# 48 136315977.0
# 56 8564120.0
# 57 4323.0
# 61 1374418.0
# 67 4136.0
# 68 152083904.0
# 72 2945466.0
# 73 220585493.0
# 75 22560475.0
# 77 21944613.0
# 78 89416228.0
# 81 11772.0
# 83 2595.0
# 84 198892.0
# 85 6316.0
# 86 3070.0
# 88 19631393.0
# 91 16397.0
# 92 1201.0
# 93 263753.0
# 94 615532.0
# 95 9239510.0
# 97 1777.0
# 99 106237866.0
# 102 5201447.0
# 105 113865791.0
# 110 1148.0
# 111 2507915.0
# 118 14255111.0
# 119 76737913.0
# 120 42072174.0
# 125 25295470.0
# 128 8523.0
# 130 10659002.0
# 133 20371.0
# 134 3075.0
# 148 175485.0
# 149 172744.0
# 150 224803872.0
# 152 49683.0
# 157 79469144.0
# 159 1572.0
# 165 8589450.0
# 168 13330.0
# 169 1611.0
# 175 49213.0
# 176 43394073.0
# 177 137493.0
# 178 5631.0
# 182 3246.0
# 185 16264639.0
# ...

# %% [markdown]
# ### Задание 2
#
# Дана статистика услуг перевозок клиентов компании по типам:
# - rzd - железнодорожные перевозки
# - auto - автомобильные перевозки
# - air - воздушные перевозки
# - client_base - адреса клиентов
#
# Необходимо сформировать две таблицы:
# - таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
# - аналогичную таблицу по типам выручки с указанием адреса клиента
#
# Обратите внимание, что в процессе объединения таблиц данные не должны теряться.

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
# Таблица с тремя типами выручки для каждого client_id без указания адреса клиента
table = client_base[['client_id']].merge(rzd, how='outer', on='client_id').merge(auto, how='outer', on='client_id').merge(air, how='outer', on='client_id')
table
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %%
# Таблица по типам выручки с указанием адреса клиента
table = client_base.merge(rzd, how='outer', on='client_id').merge(auto, how='outer', on='client_id').merge(air, how='outer', on='client_id')
table
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           NaN          NaN
# 1        112   Энтузиастов 8а       2810.0           NaN          NaN
# 2        113  Левобережная 1а      10283.0       57483.0          NaN
# 3        114          Мира 14       5774.0          83.0          NaN
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          NaN        4834.0          4.0
# 6        117  Панфиловская 33          NaN          98.0         13.0
# 7        118     Мастеркова 4          NaN           NaN        173.0

# %% [markdown]
# ### Задание 3
#
# В задаче сквозной аналитики вам предоставили данные по местоположению пользователей. Т. е. для каждого user_id известна последовательность координат (широта/долгота), когда они требовались приложению для полноценной работы. Как бы вы добавили эти сведения в таблицу визитов и покупок? Для составления ответа можно использовать вопросы:
#
# - У каждого пользователя известен набор координат. А для связывания с визитом или фактом покупки скорее всего потребуется одно-два числа. Как их получить?
# - Наборы координат одного и того же пользователя могут быть значительно удалены друг от друга. Как это отразится на вопросе расчетах пункта 1?
# - Какие дополнительные признаки можно получить из координат? Ведь это просто числа, которые сами по себе мало что дают.

# %% [markdown]
# Насколько я понимаю, в данном случае, так как пользователь может заходить из разных мест, для правильного связывания данных, помимо user_Id и самих координат, необходимо добавить идентификатор визита.
#
# Из координат помимо непосредственно точного адреса, можно получить статистические данные, которые можно использовать для аналитики по продажам в привязке к геоданным (например, статистика продаж тех или иных товаров в разных регионах, средние траты покупателей в тех или иных регионах), геотаргетингу.
